# %%
import pandas as pd

# %%
df = pd.read_csv("Telecom.csv")
df.head()
# Out:
#   Gender TT_gt_100 Response
# 0      F         Y        N
# 1      M         N        N
# 2      M         N        N
# 3      F         Y        Y
# 4      F         N        N

# %%
dum_df = pd.get_dummies(df,drop_first=True)
dum_df.head()
# Out:
#    Gender_M  TT_gt_100_Y  Response_Y
# 0         0            1           0
# 1         1            0           0
# 2         1            0           0
# 3         0            1           1
# 4         0            0           0

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohc=OneHotEncoder(drop="first")

# %%
ohc_df=ohc.fit_transform(df).toarray()

# %%
print(ohc.categories_)
# Out:
# [array(['F', 'M'], dtype=object), array(['N', 'Y'], dtype=object), array(['N', 'Y'], dtype=object)]
